# %% [markdown]
# <a href="https://colab.research.google.com/github/sasoyiano/sample/blob/main/hello_1_pic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # this is title

# %% [markdown]
# ![download.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# [google serach](https://google.com)

# %% [markdown]
# 1.   first
# 2.   second

# %% [markdown]
# hello

# %% [markdown]
# $  $
